# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="s7YmJeUA9IgceS1oxPfd")
project = rf.workspace("project-ij6y9").project("moving-detection")
dataset = project.version(2).download("yolov5")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 42 kB 345 kB/s
# ...
#      |████████████████████████████████| 178 kB 36.5 MB/s
# ...
#      |████████████████████████████████| 145 kB 76.9 MB/s
# ...
#      |████████████████████████████████| 67 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.9 MB/s
# ...
#      |████████████████████████████████| 138 kB 73.2 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.7 MB/s
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=a7b716174f3f4953d01e104dbaf3d65eb69d98ba483a9b0ab9b8c48b77de185d
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: certifi
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="s7YmJeUA9IgceS1oxPfd")
project = rf.workspace("project-ij6y9").project("moving-detection")
dataset = project.version(2).download("yolov5")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Moving-detection-2 in yolov5pytorch:: 100%|██████████| 696/696 [00:00<00:00, 1730.40it/s]

# %%
from IPython.display import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-46-g96a71b1 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.2/78.2 GB disk)

# %%
# !unzip -q ../frame0-121.zip -d ../
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 42 kB 1.0 MB/s
# ...
#      |████████████████████████████████| 138 kB 70.7 MB/s
# ...
#      |████████████████████████████████| 178 kB 76.3 MB/s
# ...
#      |████████████████████████████████| 145 kB 77.6 MB/s
# ...
#      |████████████████████████████████| 67 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.9 MB/s
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=72e289d7139b4c35c9c14f2a84056b824f5c32459a4e8d53d2f045fb23e28cde
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: certifi
# ...

# %%
#훈련
# !python train.py --img 640 --batch 20 --epochs 15 --data data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=15, batch_size=20, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# Traceback (most recent call last):
#   File "train.py", line 634, in <module>
#     main(opt)
#   File "train.py", line 503, in main
#     check_file(opt.data), check_yaml(opt.cfg), check_yaml(opt.hyp), str(opt.weights), str(opt.project)  # checks
#   File "/content/yolov5/yolov5/utils/general.py", line 483, in check_file
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.35 --source /content/Moving-detection-2/test/images/frame61_png.rf.bfa08692f416e1eca095562616549b92.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/Moving-detection-2/test/images/frame61_png.rf.bfa08692f416e1eca095562616549b92.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-46-g96a71b1 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/Moving-detection-2/test/images/frame61_png.rf.bfa08692f416e1eca095562616549b92.jpg: 640x640 18 cars, 1 truck, 12.6ms
# Speed: 0.6ms pre-process, 12.6ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
Image('/content/yolov5/runs/detect/exp2/frame61_png.rf.bfa08692f416e1eca095562616549b92.jpg')

# %%
# test
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.35 --source /content/Moving-detection-2/test/images/capture-112-_png.rf.6c73efcdab51625898f85bf1d1ab7ed0.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/Moving-detection-2/test/images/capture-112-_png.rf.6c73efcdab51625898f85bf1d1ab7ed0.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-46-g96a71b1 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/Moving-detection-2/test/images/capture-112-_png.rf.6c73efcdab51625898f85bf1d1ab7ed0.jpg: 640x640 17 cars, 12.6ms
# Speed: 0.6ms pre-process, 12.6ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
Image('/content/yolov5/runs/detect/exp3/capture-112-_png.rf.6c73efcdab51625898f85bf1d1ab7ed0.jpg')

# %%
# test
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.35 --source /content/drive/MyDrive/image/capture104.png
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/image/capture104.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-46-g96a71b1 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/image/capture104.png: 416x640 12 cars, 13.4ms
# Speed: 0.6ms pre-process, 13.4ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
Image('/content/yolov5/runs/detect/exp4/capture104.png')

# %%
# test
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --img 640 --conf 0.35 --source /content/Moving-detection-1/test/images/frame51_png.rf.c9d9e19f3dfd2435d673623aca251dbc.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/best.pt'], source=/content/Moving-detection-1/test/images/frame51_png.rf.c9d9e19f3dfd2435d673623aca251dbc.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=1, hide_labels=False, hide_conf=True, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-46-g96a71b1 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Traceback (most recent call last):
#   File "detect.py", line 261, in <module>
#     main(opt)
#   File "detect.py", line 256, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 98, in run
# ...

# %%
# test
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.55 --source /content/drive/MyDrive/image/cctv2.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/image/cctv2.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.55, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=1, hide_labels=False, hide_conf=True, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-46-g96a71b1 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/732) /content/drive/MyDrive/image/cctv2.mp4: 448x640 10 cars, 2 trucks, 11.2ms
# video 1/1 (2/732) /content/drive/MyDrive/image/cctv2.mp4: 448x640 11 cars, 2 trucks, 9.8ms
# video 1/1 (3/732) /content/drive/MyDrive/image/cctv2.mp4: 448x640 11 cars, 1 truck, 10.0ms
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp8/weights/best.pt --img 640 --conf 0.35 --source /content/test_car_vdio2.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp8/weights/best.pt'], source=/content/test_car_vdio2.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=True, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-46-g96a71b1 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Traceback (most recent call last):
#   File "detect.py", line 261, in <module>
#     main(opt)
#   File "detect.py", line 256, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 98, in run
# ...

# %%
import torch
from models.experimental import attempt_load

weights = 'runs/train/exp/weights/best.pt'
model = attempt_load(weights)
torch.save(model, 'model_with_shape.pt')
print("load and save model successfully!")
# Out:
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# load and save model successfully!
